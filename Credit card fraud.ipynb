# %%
# import libararies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

# %%
data=pd.read_csv('C:\\BSY\Data science\\python\\credit card\\creditcard.csv')

# %%
data
#class 1 is fraud class 0 is no fraud
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
#preparing the data
X=data.drop(['Class'],axis=1)
Y=data['Class']

# %%
#check the shape
print(X.shape, Y.shape)
# Out:
# (284807, 30) (284807,)

# %%
#converting Y into a array for Scikit 
Y=np.ravel(Y)

# %%
Y
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
#scalling the data
from sklearn.preprocessing  import StandardScaler
sc=StandardScaler()
X=sc.fit_transform(X)

# %%
X
# Out:
# array([[-1.99658302, -0.69424232, -0.04407492, ...,  0.33089162,
#         -0.06378115,  0.24496426],
#        [-1.99658302,  0.60849633,  0.16117592, ..., -0.02225568,
#          0.04460752, -0.34247454],
#        [-1.99656197, -0.69350046, -0.81157783, ..., -0.13713686,
#         -0.18102083,  1.16068593],
#        ...,
#        [ 1.6419735 ,  0.98002374, -0.18243372, ...,  0.01103672,
#         -0.0804672 , -0.0818393 ],
#        [ 1.6419735 , -0.12275539,  0.32125034, ...,  0.26960398,
#          0.31668678, -0.31324853],
#        [ 1.64205773, -0.27233093, -0.11489898, ..., -0.00598394,
#          0.04134999,  0.51435531]])

# %%
#creating the  train tets data
X_train,X_test,Y_train,Y_test=train_test_split(X,Y, test_size = 0.25, random_state = 0)

# %%
#check 
print(X_train.shape,X_test.shape,Y_train.shape,Y_test.shape)
# Out:
# (213605, 30) (71202, 30) (213605,) (71202,)

# %%
#creating the model
from sklearn.linear_model import LogisticRegression
lr_model=LogisticRegression()
lr_model.fit(X_train,Y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
Y_pred=lr_model.predict(X_test)

# %%
#checking the result
cm=confusion_matrix(Y_test,Y_pred)
sns.heatmap(cm,annot=True,fmt='d')
print(classification_report(Y_test,Y_pred))
print('accuracy score:',accuracy_score(Y_test,Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     71082
#            1       0.88      0.66      0.75       120
#
#     accuracy                           1.00     71202
#    macro avg       0.94      0.83      0.88     71202
# weighted avg       1.00      1.00      1.00     71202
#
# accuracy score: 0.9992696834358585

# %%
#the model has very good acuracy 
#now we wil see individual coefficent

# %%
#creating a coef matrix
coef_matrix=pd.DataFrame(zip(data.columns,np.transpose(lr_model.coef_)))

# %%
coef_matrix
# Out:
#          0                        1
# 0     Time    [-0.1666708873568169]
# 1       V1    [0.19143910583066223]
# 2       V2   [0.025820343670001755]
# 3       V3     [0.0282374892154709]
# 4       V4     [0.9765043480153471]
# 5       V5    [0.12793944626360032]
# 6       V6   [-0.17967833928871446]
# 7       V7   [-0.15913550434480742]
# 8       V8   [-0.19979903106158986]
# 9       V9    [-0.2707678826705612]
# 10     V10    [-0.8416212240555314]
# 11     V11    [0.01686544289255998]
# 12     V12    [0.06863572298253101]
# 13     V13    [-0.2564429981168198]
# 14     V14    [-0.5296856501821117]
# 15     V15   [-0.12291603605497364]
# 16     V16   [-0.12147086621064446]
# 17     V17   [-0.02271199303326716]
# 18     V18  [-0.046380238816617736]
# 19     V19   [0.050121586842969926]
# 20     V20    [-0.3517455190748161]
# 21     V21    [0.26085821053739144]
# 22     V22    [0.40441130840971895]
# 23     V23   [-0.03813712668219175]
# 24     V24    [0.04633524082953867]
# ...

# %%
#we can see that V4 is highly positively coerrlated and V10 is neagtiviely correlated
